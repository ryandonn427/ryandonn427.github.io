# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Get the data

# %%
link = 'https://data.cdc.gov/api/views/hn4x-zwk7/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(link)

# %% [markdown]
# We can see that the read_csv method assumed the data type of 6 floats and 3 integers

# %%
df.dtypes.value_counts()
# Out:
# object     24
# float64     6
# int64       3
# dtype: int64

# %% [markdown]
# Can we clean up any other object data types/

# %%
df.describe(include='O').T
# Out:
#                              count unique  \
# LocationAbbr                104272     55
# LocationDesc                104272     55
# Datasource                  104272      1
# Class                       104272      3
# Topic                       104272      3
# Question                    104272      9
# Data_Value_Type             104272      1
# Data_Value_Footnote_Symbol   10767      1
# Data_Value_Footnote          10767      1
# Total                         3724      1
# Age(years)                   22344      6
# Education                    14896      4
# Gender                        7448      2
# Income                       26068      7
# Race/Ethnicity               29792      8
# GeoLocation                 102340    105
# ClassID                     104272      3
# TopicID                     104272      3
# QuestionID                  104272      9
# DataValueTypeID             104272      1
# StratificationCategory1     104272      6
# ...

# %% [markdown]
# We can clean up the Age(years), Income, Race/Ethnicity, Stratification1, and
