# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('./Intake Combined Agent Metrics/phone inbound jan 2020 to date.csv')

# %%
df['Time Test'] = datetime(year=2021,day=17,month=2,minute=1,hour=1,second=1)
def translate_time(time):
    days, hours, minutes, seconds = [int(i[:2]) for i in time.split(' ')]
    timestamp = days*24*60*60+hours*60*60 + minutes*60+seconds
    return timestamp
pd.to_datetime(df['Talk time'].map(translate_time))
# Out:
# 0     1970-01-01 00:00:00.000000000
# 1     1970-01-01 00:00:00.000000097
# 2     1970-01-01 00:00:00.000000001
# 3     1970-01-01 00:00:00.000000035
# 4     1970-01-01 00:00:00.000000116
# 5     1970-01-01 00:00:00.000000151
# 6     1970-01-01 00:00:00.000000000
# 7     1970-01-01 00:00:00.000000073
# 8     1970-01-01 00:00:00.000000310
# 9     1970-01-01 00:00:00.000000000
# 10    1970-01-01 00:00:00.000000319
# 11    1970-01-01 00:00:00.000000000
# 12    1970-01-01 00:00:00.000000044
# 13    1970-01-01 00:00:00.000000620
# 14    1970-01-01 00:00:00.000000064
# 15    1970-01-01 00:00:00.000001441
# 16    1970-01-01 00:00:00.000000027
# 17    1970-01-01 00:00:00.000000000
# 18    1970-01-01 00:00:00.000000012
# 19    1970-01-01 00:00:00.000000019
# 20    1970-01-01 00:00:00.000000004
# 21    1970-01-01 00:00:00.000000047
# 22    1970-01-01 00:00:00.000000026
# 23    1970-01-01 00:00:00.000000184
# 24    1970-01-01 00:00:00.000000026
# 25    1970-01-01 00:00:00.000000023
# ...
